# %% [markdown]
# # Ungraded Lab: Guided EDA Exercises

# %% [markdown]
# ## Overview
# In this hands-on lab, you'll conduct exploratory data analysis (EDA) on the EngageMetrics employee dataset. You'll learn to apply descriptive statistical methods, identify patterns, and detect anomalies in real-world data. This lab builds foundation skills needed for the final capstone project. Remember that the course screencasts are here to support your learning journey. Having them open in another tab for quick reference is a strategy used by professionals and learners alike.
#
# ## Learning Outcomes
# By the end of this lab, you will be able to:
# - Apply basic descriptive statistics to understand data distributions
# - Generate summary statistics for numerical and categorical variables
# - Identify patterns and potential anomalies in the dataset
# - Document your analysis process and findings effectively
#
# ## Dataset Information
# We'll use the <b>employee_insights.csv</b> dataset from EngageMetrics, containing employee information including:
# - Demographics (age)
# - Work metrics (salary, hours worked, projects completed)
# - Performance indicators (satisfaction score, overtime hours)
# - Categorical data (department, work mode, promotion eligibility)

# %% [markdown]
# ## Activities
# ### Activity 1: Initial Data Exploration
# Let's begin by loading and examining the dataset structure.
#
# <b>Step 1:</b> Import libraries and load data:

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('employee_insights.csv')

# %% [markdown]
# <b>Step 2:</b> Examine the dataset structure:

# %%
# View first few rows and basic information
display(df.head())
df.info()
# Out:
#   employee_id   age  salary promotion_eligible last_training_date department  \
# 0       E0001  54.0     NaN                NaN         15/08/2023         HR
# 1       E0002   NaN  $64761                  N         15/08/2023        NaN
# 2       E0003  54.0     NaN                  N         15/08/2023  Marketing
# 3       E0004   NaN     NaN                 No                NaN        NaN
# 4       E0005  29.0  $61486                  Y         15/08/2023        NaN
#
#   work_experience  projects_completed  hours_worked_weekly    work_mode  \
# 0             NaN                14.0                  NaN  remote work
# 1         1 years                 NaN                 53.3       HYBRID
# 2               8                 6.0                 32.6       Hybrid
# 3              16                 1.0                 37.8       Remote
# 4             NaN                 1.0                 53.3       Hybrid
#
#   last_promotion_date  satisfaction_score  overtime_hours
# 0          2022-05-10                 NaN             8.4
# 1          05-10-2022                 NaN             8.1
# 2          10/05/2022                10.0             5.2
# 3          05-10-2022                 5.0             NaN
# 4          2022-05-10                 NaN             0.3
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   employee_id          100 non-null    str
#  1   age                  44 non-null     float64
#  2   salary               63 non-null     str
#  3   promotion_eligible   84 non-null     str
#  4   last_training_date   71 non-null     str
#  5   department           85 non-null     str
#  6   work_experience      71 non-null     str
#  7   projects_completed   48 non-null     float64
#  8   hours_worked_weekly  67 non-null     float64
#  9   work_mode            84 non-null     str
#  10  last_promotion_date  74 non-null     str
#  11  satisfaction_score   61 non-null     float64
#  12  overtime_hours       70 non-null     float64
# dtypes: float64(5), str(8)
# memory usage: 10.3 KB

# %% [markdown]
# <b>Tip:</b> Always start with a high-level overview of your data to understand its structure.

# %% [markdown]
# ### Activity 2: Descriptive Statistics
# Now we'll calculate and interpret basic statistics.
#
# <b>Step 1:</b> Generate summary statistics:

# %%
# Generate summary statistics for numerical columns
df['salary'] = df['salary'].str.replace("$","")
df['salary'] = df['salary'].astype(float)
df['salary'] = df['salary'].fillna(df['salary'].mean())

df['work_experience'] = df['work_experience'].str.replace("years","").str.strip()
df['work_experience'] = df['work_experience'].astype(float)
df['work_experience'] = df['work_experience'].fillna(df['work_experience'].mean())

df['age'] = df['age'].fillna(df['age'].mean())
df['projects_completed'] = df['projects_completed'].fillna(df['projects_completed'].mean())
df['hours_worked_weekly'] = df['hours_worked_weekly'].fillna(df['hours_worked_weekly'].mean())
df['satisfaction_score'] = df['satisfaction_score'].fillna(df['satisfaction_score'].mean())
df['overtime_hours'] = df['overtime_hours'].fillna(df['overtime_hours'].mean())

numerical_stats = df[['age', 'salary', 'work_experience', 'projects_completed', 'hours_worked_weekly', 'satisfaction_score', 'overtime_hours']].describe()
print(numerical_stats)
# Out:
#               age         salary  work_experience  projects_completed  \
# count  100.000000     100.000000       100.000000          100.000000
# mean    41.659091   81553.111111        10.084507            7.062500
# std      7.932726   16011.489064         4.648768            3.397582
# min     22.000000   51438.000000         1.000000            0.000000
# 25%     41.659091   73905.750000         6.750000            7.062500
# 50%     41.659091   81553.111111        10.084507            7.062500
# 75%     41.659091   89678.750000        13.000000            7.296875
# max     60.000000  118824.000000        20.000000           15.000000
#
#        hours_worked_weekly  satisfaction_score  overtime_hours
# count           100.000000          100.000000      100.000000
# mean             43.382090            5.573770        5.618571
# std               6.957097            2.271737        2.373775
# min              30.100000            1.000000        0.000000
# 25%              39.725000            5.000000        4.900000
# 50%              43.382090            5.573770        5.618571
# 75%              46.475000            6.000000        7.200000
# max              59.400000           10.000000        9.800000

# %% [markdown]
# <b>Step 2:</b> Analyze categorical variables:

# %%
# Clean and calculate value counts for work_mode and department
df['department'] = df['department'].str.capitalize()
df['promotion_eligible'] = df['promotion_eligible'].replace({'Y': 'Yes', 'N': 'No'})
df['work_mode'] = df['work_mode'].str.replace('remote work','Remote').str.capitalize()

df['department'] = df['department'].fillna(df['department'].mode()[0])
df['promotion_eligible'] = df['promotion_eligible'].fillna(df['promotion_eligible'].mode()[0])
df['work_mode'] = df['work_mode'].fillna(df['work_mode'].mode()[0])

print("\nDepartment distribution:")
print(df['department'].value_counts())

print("\nPromotion distribution:")
print(df['promotion_eligible'].value_counts())

print("\nWork mode distribution:")
print(df['work_mode'].value_counts())
# Out:
# Department distribution:
# department
# Finance        46
# Engineering    23
# Hr             16
# Marketing      15
# Name: count, dtype: int64
#
# Promotion distribution:
# promotion_eligible
# Yes    64
# No     36
# Name: count, dtype: int64
#
# Work mode distribution:
# work_mode
# Remote     50
# Hybrid     33
# On-site    17
# Name: count, dtype: int64

# %% [markdown]
# <b>Tip:</b> Pay attention to missing values and potential outliers in your summary statistics.

# %% [markdown]
# ### Activity 3: Pattern Identification
# Let's explore relationships between variables.
#
# <b>Step 1:</b> Examine relationships:

# %%
# Calculate average satisfaction score by department
dep_satisfaction = df.groupby('department')['satisfaction_score'].agg(['mean'])
print("Satisfaction Score by Department:")
display(dep_satisfaction.round(2))
# Out:
# Satisfaction Score by Department:
#              mean
# department
# Engineering  6.37
# Finance      5.46
# Hr           4.89
# Marketing    5.44

# %% [markdown]
# <b>Step 2:</b> Identify potential anomalies:

# %%
# Check for outliers in salary and hours_worked_weekly (remember to fill NaN values with appropriate values)
def identify_outliers(df, column):  # We define a function with parameters for the DataFrame and column to analyze
    Q1 = df[column].quantile(0.25)  # The quantile() method calculates the 25th percentile
    Q3 = df[column].quantile(0.75)  # The quantile() method calculates the 75th percentile
    IQR = Q3 - Q1                   # We manually calculate the Interquartile Range
    lower_bound = Q1 - 1.5 * IQR    # Calculate the lower threshold for outliers using the standard formula
    upper_bound = Q3 + 1.5 * IQR    # Calculate the upper threshold for outliers using the standard formula
    
    # Using Boolean indexing to filter the DataFrame for values outside our bounds
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers  # The function returns a DataFrame containing only the outlier rows

salary_outliers = identify_outliers(df, 'salary')  # We call our custom function on the salary column
print("Salary outliers found:", len(salary_outliers))  # The len() function counts how many outliers we found
print("\nOutlier Details:")
display(salary_outliers[['employee_id', 'department', 'salary']].head())  # We use double brackets to select multiple columns of interest

hours_worked_outliers = identify_outliers(df, 'hours_worked_weekly')
print("\nHours worked weekly outliers found:", len(hours_worked_outliers))  # The len() function counts how many outliers we found
print("\nOutlier Details:")
display(hours_worked_outliers[['employee_id','department', 'hours_worked_weekly']].head())  # We use double brackets to select multiple columns of interest
# Out:
# Salary outliers found: 5
#
# Outlier Details:
#    employee_id   department    salary
# 6        E0007      Finance  115377.0
# 37       E0038      Finance  118824.0
# 46       E0047  Engineering  114025.0
# 68       E0069           Hr  115365.0
# 88       E0089    Marketing  117852.0
# Hours worked weekly outliers found: 5
#
# Outlier Details:
#    employee_id department  hours_worked_weekly
# 9        E0010    Finance                 57.9
# 21       E0022  Marketing                 59.4
# 51       E0052         Hr                 58.5
# 56       E0057         Hr                 57.1
# 79       E0080         Hr                 57.3

# %% [markdown]
# <b>Test Your Work:</b>
# - Summary statistics should show key metrics (mean, median, std) for numerical columns
# - Categorical analysis should show counts for each unique value
# - Pattern analysis should reveal insights about employee satisfaction
# - Outlier detection should identify unusual values in the dataset
#
# ## Success Checklist
# - Successfully loaded and examined the dataset structure
# - Generated and interpreted summary statistics
# - Analyzed categorical variable distributions
# - Identified patterns and potential outliers
# - Documented findings clearly
#
# ## Common Issues & Solutions
# - Problem: Missing values affecting calculations
#   - Solution: Use appropriate pandas methods (dropna(), fillna()) based on context
# - Problem: Incorrect data types preventing analysis
#   - Solution: Check and convert data types using astype() when needed
#
# ## Summary
# Congratulations on completing this foundational EDA lab! You've now mastered the essential techniques for uncovering insights in data, and these skills will serve as your analytical toolkit for tackling real-world business challenges in your data science journey.
#
# ### Key Points
# - Always start with basic data exploration
# - Consider both numerical and categorical variables
# - Document observations and potential issues
# - Think critically about what the patterns mean

# %% [markdown]
# ## Solution Code
# Stuck on your code or want to check your solution? Here's a complete reference implementation to guide you. This represents just one effective approach—try solving independently first, then use this to overcome obstacles or compare techniques. The solution is provided to help you move forward and explore alternative approaches to achieve the same results. Happy coding!

# %% [markdown]
# ### Activity 1: Initial Data Exploration - Solution Code

# %%
# Import required libraries
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('employee_insights.csv')

# Display the first few rows
print("First few rows of the dataset:")
display(df.head())

# Display basic information about the dataset
print("\nDataset information:")
df.info()
# Out:
# First few rows of the dataset:
#   employee_id   age  salary promotion_eligible last_training_date department  \
# 0       E0001  54.0     NaN                NaN         15/08/2023         HR
# 1       E0002   NaN  $64761                  N         15/08/2023        NaN
# 2       E0003  54.0     NaN                  N         15/08/2023  Marketing
# 3       E0004   NaN     NaN                 No                NaN        NaN
# 4       E0005  29.0  $61486                  Y         15/08/2023        NaN
#
#   work_experience  projects_completed  hours_worked_weekly    work_mode  \
# 0             NaN                14.0                  NaN  remote work
# 1         1 years                 NaN                 53.3       HYBRID
# 2               8                 6.0                 32.6       Hybrid
# 3              16                 1.0                 37.8       Remote
# 4             NaN                 1.0                 53.3       Hybrid
#
#   last_promotion_date  satisfaction_score  overtime_hours
# 0          2022-05-10                 NaN             8.4
# 1          05-10-2022                 NaN             8.1
# 2          10/05/2022                10.0             5.2
# 3          05-10-2022                 5.0             NaN
# 4          2022-05-10                 NaN             0.3
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   employee_id          100 non-null    str
#  1   age                  44 non-null     float64
#  2   salary               63 non-null     str
#  3   promotion_eligible   84 non-null     str
#  4   last_training_date   71 non-null     str
#  5   department           85 non-null     str
#  6   work_experience      71 non-null     str
#  7   projects_completed   48 non-null     float64
#  8   hours_worked_weekly  67 non-null     float64
#  9   work_mode            84 non-null     str
#  10  last_promotion_date  74 non-null     str
#  11  satisfaction_score   61 non-null     float64
#  12  overtime_hours       70 non-null     float64
# dtypes: float64(5), str(8)
# memory usage: 10.3 KB

# %% [markdown]
# ### Activity 2: Descriptive Statistics  - Solution Code

# %%
# Generate summary statistics for numerical columns
df['salary'] = (df['salary'].str.replace("$","").astype(float))

numerical_stats = df[['age', 'salary', 'hours_worked_weekly', 'satisfaction_score', 'overtime_hours']].describe()
display(numerical_stats)

# Additional analysis of missing values
missing_values = df.isnull().sum()
print("\nMissing values in each column:")
display(missing_values)

# Calculate value counts for work_mode
work_mode_counts = df['work_mode'].value_counts()
print("Work Mode Distribution:")
display(work_mode_counts)

# Calculate value counts for department
dept_counts = df['department'].value_counts()
print("\nDepartment Distribution:")
display(dept_counts)

# Calculate percentages - Additional analysis
work_mode_pct = df['work_mode'].value_counts(normalize=True) * 100
print("\nWork Mode Percentages:")
display(work_mode_pct)
# Out:
#              age         salary  hours_worked_weekly  satisfaction_score  \
# count  44.000000      63.000000            67.000000           61.000000
# mean   41.659091   81553.111111            43.382090            5.573770
# std    12.036656   20232.682927             8.520669            2.918099
# min    22.000000   51438.000000            30.100000            1.000000
# 25%    30.000000   64705.500000            35.200000            3.000000
# 50%    41.000000   77186.000000            43.300000            6.000000
# 75%    54.000000   98882.500000            50.450000            8.000000
# max    60.000000  118824.000000            59.400000           10.000000
#
#        overtime_hours
# count       70.000000
# mean         5.618571
# std          2.843365
# min          0.000000
# 25%          3.300000
# 50%          6.150000
# 75%          8.025000
# max          9.800000
# Missing values in each column:
# employee_id             0
# age                    56
# salary                 37
# promotion_eligible     16
# last_training_date     29
# department             15
# work_experience        29
# projects_completed     52
# hours_worked_weekly    33
# work_mode              16
# last_promotion_date    26
# satisfaction_score     39
# overtime_hours         30
# dtype: int64
# Work Mode Distribution:
# work_mode
# remote work    19
# HYBRID         19
# On-site        17
# Remote         15
# Hybrid         14
# Name: count, dtype: int64
# Department Distribution:
# department
# Finance        18
# HR             16
# Marketing      15
# Engineering    13
# finance        13
# engineering    10
# Name: count, dtype: int64
# Work Mode Percentages:
# work_mode
# remote work    22.619048
# HYBRID         22.619048
# On-site        20.238095
# Remote         17.857143
# Hybrid         16.666667
# Name: proportion, dtype: float64

# %% [markdown]
# ### Activity 3: Pattern Identification - Solution Code

# %%
# Calculate average satisfaction score by department
dept_satisfaction = df.groupby('department')['satisfaction_score'].agg(['mean'])
dept_satisfaction = dept_satisfaction.round(2)
print("Satisfaction Score by Department:")
display(dept_satisfaction)

# Identify potential anomalies
def identify_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers, lower_bound, upper_bound

# Check for salary outliers
df['salary'] = df['salary'].fillna(df['salary'].mean())
salary_outliers, salary_lower, salary_upper = identify_outliers(df, 'salary')
print("Salary Outliers:")
print(f"Number of outliers: {len(salary_outliers)}")
print(f"Range for normal values: {salary_lower:.2f} to {salary_upper:.2f}")
display(salary_outliers[['employee_id', 'salary', 'department']])

# Check for hours worked outliers
df['hours_worked_weekly'] = df['hours_worked_weekly'].fillna(df['hours_worked_weekly'].mean())
hours_outliers, hours_lower, hours_upper = identify_outliers(df, 'hours_worked_weekly')
print("\nHours Worked Outliers:")
print(f"Number of outliers: {len(hours_outliers)}")
print(f"Range for normal values: {hours_lower:.2f} to {hours_upper:.2f}")
display(hours_outliers[['employee_id', 'hours_worked_weekly', 'department']])
# Out:
# Satisfaction Score by Department:
#              mean
# department
# Engineering  6.44
# Finance      5.08
# HR           4.00
# Marketing    5.29
# engineering  6.88
# finance      5.60
# Salary Outliers:
# Number of outliers: 5
# Range for normal values: 50246.25 to 113338.25
#    employee_id    salary   department
# 6        E0007  115377.0      Finance
# 37       E0038  118824.0          NaN
# 46       E0047  114025.0  engineering
# 68       E0069  115365.0           HR
# 88       E0089  117852.0    Marketing
# Hours Worked Outliers:
# Number of outliers: 5
# Range for normal values: 29.60 to 56.60
#    employee_id  hours_worked_weekly department
# 9        E0010                 57.9    Finance
# 21       E0022                 59.4  Marketing
# 51       E0052                 58.5         HR
# 56       E0057                 57.1         HR
# 79       E0080                 57.3         HR
